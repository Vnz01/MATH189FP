# %% [markdown]
# # MATH 189 Final Project

# %% [markdown]
# by: Pranav Damal, Lucien Chen, Venz Burgos

# %% [markdown]
# ## Objective: ...

# %% [markdown]
# ## Thesis: ...

# %%
# pip install nfl_data_py
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from pandas.api.types import is_numeric_dtype
sns.set_style("darkgrid")

# %% [markdown]
# ## Top NFL QB per year 2006-2023

# %%
year = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023]
highestQBR = {}
for x in year:
    df = nfl.import_qbr([x])
    rank1 = df['rank'].idxmin()
    name = df.loc[rank1, 'name_display']
    highestQBR[x] = name

# highestQBR is a dict with the year and rank 1 QB
# incase this data is needed
print(highestQBR)
# Out:
# {2006: 'Peyton Manning', 2007: 'Tom Brady', 2008: 'Peyton Manning', 2009: 'Drew Brees', 2010: 'Tom Brady', 2011: 'Aaron Rodgers', 2012: 'Peyton Manning', 2013: 'Peyton Manning', 2014: 'Tony Romo', 2015: 'Carson Palmer', 2016: 'Matt Ryan', 2017: 'Carson Wentz', 2018: 'Patrick Mahomes', 2019: 'Lamar Jackson', 2020: 'Aaron Rodgers', 2021: 'Aaron Rodgers', 2022: 'Patrick Mahomes', 2023: 'Brock Purdy'}

# %% [markdown]
# ## Top College QB Prospects 2006-2023

# %%
top_qb_prospects = {}

for year in range(2010, 2024):
    draft = nfl.import_draft_picks([year])
    firstQBs = draft[(draft['position'] == 'QB') & (draft['round'] == 1)]
    qbList = firstQBs['pfr_player_name'].tolist()
    top_qb_prospects[year] = qbList

for year, prospects in top_qb_prospects.items():
    print(f"first round QBs in {year}: {prospects}")
# Out:
# first round QBs in 2010: ['Sam Bradford', 'Tim Tebow']
# first round QBs in 2011: ['Cam Newton', 'Jake Locker', 'Blaine Gabbert', 'Christian Ponder']
# first round QBs in 2012: ['Andrew Luck', 'Robert Griffin III', 'Ryan Tannehill', 'Brandon Weeden']
# first round QBs in 2013: ['EJ Manuel']
# first round QBs in 2014: ['Blake Bortles', 'Johnny Manziel', 'Teddy Bridgewater']
# first round QBs in 2015: ['Jameis Winston', 'Marcus Mariota']
# first round QBs in 2016: ['Jared Goff', 'Carson Wentz', 'Paxton Lynch']
# first round QBs in 2017: ['Mitchell Trubisky', 'Patrick Mahomes', 'Deshaun Watson']
# first round QBs in 2018: ['Baker Mayfield', 'Sam Darnold', 'Josh Allen', 'Josh Rosen', 'Lamar Jackson']
# first round QBs in 2019: ['Kyler Murray', 'Daniel Jones', 'Dwayne Haskins']
# first round QBs in 2020: ['Joe Burrow', 'Tua Tagovailoa', 'Justin Herbert', 'Jordan Love']
# first round QBs in 2021: ['Trevor Lawrence', 'Zach Wilson', 'Trey Lance', 'Justin Fields', 'Mac Jones']
# first round QBs in 2022: ['Kenny Pickett']
# first round QBs in 2023: ['Bryce Young', 'C.J. Stroud', 'Anthony Richardson']

# %% [markdown]
# ## QB Data

# %%
college = pd.read_csv('./data/QBCollege.csv')
nfl = pd.read_csv('./data/QBNFL.csv')

college.head(5)
# Out:
#               player  year  player_id position   team_name  player_game_count  \
# 0  Michael Penix Jr.  2023      82134       QB  WASHINGTON                 15
# 1         Davis Brin  2023      77642       QB  GA SOUTHRN                 13
# 2    Brayden Schager  2023     146078       QB      HAWAII                 13
# 3        Alan Bowman  2023      77679       QB  OKLA STATE                 14
# 4       Cameron Ward  2023     133244       QB  WASH STATE                 12
#
#    accuracy_percent  aimed_passes  attempts  avg_depth_of_target  ...  \
# 0              74.5           517       556                 10.7  ...
# 1              75.0           525       556                  8.4  ...
# 2              72.9           495       526                 10.3  ...
# 3              71.8           457       502                  8.6  ...
# 4              78.6           444       486                  7.7  ...
#
#    sack_percent  sacks  scrambles  spikes  thrown_aways  touchdowns  \
# 0           2.1     12          8       0            31          36
# 1           4.9     30         21       5            15          24
# 2           6.7     40         32       2            17          26
# 3           1.2      6          5       0            42          15
# 4           7.6     43         36       0            27          25
#
#    turnover_worthy_plays  twp_rate   yards  ypa
# 0                   12.0       2.0  4906.0  8.8
# 1                   31.0       4.9  3786.0  6.8
# 2                   14.0       2.2  3525.0  6.7
# 3                   22.0       4.1  3460.0  6.9
# 4                   21.0       3.6  3723.0  7.7
#
# [5 rows x 43 columns]

# %%
nfl.head(5)
# Out:
#        Player  Year  Plays  EPA+CPOE composite  Adj. EPA/play  EPA/play  \
# 0  S.Clifford  2023      2               0.581          0.648     0.648
# 1  J.Brissett  2023     30               0.383          0.742     0.742
# 2     B.Purdy  2023    646               0.188          0.333     0.316
# 3     C.Wentz  2023     46               0.182          0.268     0.266
# 4  C.Beathard  2023     68               0.162          0.171     0.171
#
#   Success rate   Cmp%  Expected cmp%  CPOE  Air yards
# 0       50.00%  100.0           41.4  58.6       34.0
# 1       56.70%   81.8           64.2  17.7        8.0
# 2       54.30%   70.7           66.8   3.9        8.2
# 3       56.50%   73.9           67.2   6.7        6.7
# 4       51.50%   76.9           67.2   9.8        6.4

# %%
college.shape, nfl.shape
# Out:
# ((4949, 43), (677, 11))

# %%
college.dtypes
# Out:
# player                    object
# year                       int64
# player_id                  int64
# position                  object
# team_name                 object
# player_game_count          int64
# accuracy_percent         float64
# aimed_passes               int64
# attempts                   int64
# avg_depth_of_target      float64
# avg_time_to_throw        float64
# bats                       int64
# big_time_throws            int64
# btt_rate                 float64
# completion_percent       float64
# completions                int64
# declined_penalties         int64
# def_gen_pressures          int64
# drop_rate                float64
# dropbacks                  int64
# drops                      int64
# first_downs                int64
# franchise_id               int64
# grades_hands_fumble      float64
# grades_offense           float64
# grades_pass              float64
# grades_run               float64
# hit_as_threw               int64
# interceptions              int64
# passing_snaps              int64
# penalties                float64
# pressure_to_sack_rate    float64
# qb_rating                float64
# sack_percent             float64
# sacks                      int64
# scrambles                  int64
# spikes                     int64
# thrown_aways               int64
# touchdowns                 int64
# turnover_worthy_plays    float64
# twp_rate                 float64
# yards                    float64
# ypa                      float64
# dtype: object

# %%
nfl.dtypes
# Out:
# Player                 object
# Year                    int64
# Plays                   int64
# EPA+CPOE composite    float64
# Adj. EPA/play         float64
# EPA/play              float64
# Success rate           object
# Cmp%                  float64
# Expected cmp%         float64
# CPOE                  float64
# Air yards             float64
# dtype: object

# %%
college.describe()
# Out:
#               year      player_id  player_game_count  accuracy_percent  \
# count  4949.000000    4949.000000        4949.000000       4870.000000
# mean   2018.643564   69055.548192           5.049707         65.561971
# std       2.832113   42463.173966           4.198822         27.352853
# min    2014.000000    9434.000000           1.000000          0.000000
# 25%    2016.000000   39879.000000           1.000000         59.025000
# 50%    2019.000000   57455.000000           3.000000         69.200000
# 75%    2021.000000   97993.000000           8.000000         77.800000
# max    2023.000000  181169.000000          15.000000        100.000000
#
#        aimed_passes     attempts  avg_depth_of_target  avg_time_to_throw  \
# count   4949.000000  4949.000000          4870.000000        4949.000000
# mean      95.255809   101.882198            10.568049           2.858792
# std      133.762886   142.580408             7.667557           0.764729
# min        0.000000     1.000000           -13.000000           0.000000
# 25%        2.000000     2.000000             7.600000           2.490000
# 50%       20.000000    21.000000             9.600000           2.750000
# 75%      152.000000   162.000000            12.200000           3.100000
# max      652.000000   692.000000            54.000000           9.900000
#
#               bats  big_time_throws  ...  sack_percent        sacks  \
# count  4949.000000      4949.000000  ...   4949.000000  4949.000000
# mean      1.594666         4.941806  ...      6.725803     7.207719
# std       2.661854         7.830914  ...      9.586311    11.094258
# min       0.000000         0.000000  ...      0.000000     0.000000
# 25%       0.000000         0.000000  ...      0.000000     0.000000
# 50%       0.000000         1.000000  ...      2.000000     2.000000
# 75%       2.000000         7.000000  ...     10.000000    10.000000
# max      26.000000        54.000000  ...     51.000000    75.000000
#
#          scrambles       spikes  thrown_aways   touchdowns  \
# count  4949.000000  4949.000000   4949.000000  4949.000000
# mean      1.825823     3.046070      5.108103     5.064862
# std       6.341212     5.595094      8.265931     7.119550
# min       0.000000     0.000000      0.000000     0.000000
# 25%       0.000000     0.000000      0.000000     0.000000
# 50%       0.000000     0.000000      1.000000     1.000000
# 75%       0.000000     4.000000      7.000000     8.000000
# max      76.000000    34.000000     62.000000    45.000000
#
#        turnover_worthy_plays     twp_rate        yards          ypa
# count            4949.000000  4949.000000  4949.000000  1043.000000
# mean                6.013397   593.487189   163.673570     7.701534
# std                14.124140  1027.219374   587.519613     7.418215
# min                 0.000000   -10.000000   -16.000000   -16.000000
# 25%                 0.000000     3.000000     4.700000     4.500000
# 50%                 2.800000    39.000000     7.200000     6.800000
# 75%                 5.600000   702.000000    12.000000     8.500000
# max               100.000000  5940.000000  4906.000000    67.000000
#
# [8 rows x 40 columns]

# %%
nfl.describe()
# Out:
#               Year       Plays  EPA+CPOE composite  Adj. EPA/play    EPA/play  \
# count   677.000000  677.000000          677.000000     677.000000  677.000000
# mean   2019.144756  304.986706            0.062970      -0.029453   -0.061292
# std       2.596599  282.274172            0.105231       0.386862    0.451488
# min    2015.000000    1.000000           -0.333000      -2.922000   -5.143000
# 25%    2017.000000   43.000000            0.009000      -0.136000   -0.155000
# 50%    2019.000000  203.000000            0.054000       0.032000    0.011000
# 75%    2021.000000  591.000000            0.111000       0.145000    0.131000
# max    2023.000000  935.000000            0.785000       1.990000    1.990000
#
#              Cmp%  Expected cmp%        CPOE   Air yards
# count  665.000000     665.000000  677.000000  665.000000
# mean    63.369173      65.933233   -2.517282    7.939699
# std     12.614572       4.567258   11.629756    2.763835
# min      0.000000      31.600000  -79.100000   -3.300000
# 25%     60.000000      63.800000   -5.500000    7.000000
# 50%     64.900000      66.100000   -0.700000    8.000000
# 75%     68.600000      68.000000    2.300000    8.800000
# max    100.000000      87.600000   58.600000   35.000000

# %%
college.columns
# Out:
# Index(['player', 'year', 'player_id', 'position', 'team_name',
#        'player_game_count', 'accuracy_percent', 'aimed_passes', 'attempts',
#        'avg_depth_of_target', 'avg_time_to_throw', 'bats', 'big_time_throws',
#        'btt_rate', 'completion_percent', 'completions', 'declined_penalties',
#        'def_gen_pressures', 'drop_rate', 'dropbacks', 'drops', 'first_downs',
#        'franchise_id', 'grades_hands_fumble', 'grades_offense', 'grades_pass',
#        'grades_run', 'hit_as_threw', 'interceptions', 'passing_snaps',
#        'penalties', 'pressure_to_sack_rate', 'qb_rating', 'sack_percent',
#        'sacks', 'scrambles', 'spikes', 'thrown_aways', 'touchdowns',
#        'turnover_worthy_plays', 'twp_rate', 'yards', 'ypa'],
#       dtype='object')

# %%
columns = [
    "player",
    "year",
    "player_id",
    "position",
    "accuracy_percent",
    "aimed_passes",
    "attempts",
    "avg_time_to_throw",
    "btt_rate",
    "completion_percent",
    "drop_rate",
    "qb_rating",
    "yards"
]

# %%
college = college[columns]

# %%
college.position.unique()
# Out:
# array(['QB', 'TE', 'HB', 'WR', 'P', 'FB', 'K', 'ED', 'LB', 'LS', 'ST',
#        nan, 'S', 'T', 'CB'], dtype=object)

# %%
college_qb = college[college.position == "QB"]

# %%
college_qb.head()
# Out:
#               player  year  player_id position  accuracy_percent  \
# 0  Michael Penix Jr.  2023      82134       QB              74.5
# 1         Davis Brin  2023      77642       QB              75.0
# 2    Brayden Schager  2023     146078       QB              72.9
# 3        Alan Bowman  2023      77679       QB              71.8
# 4       Cameron Ward  2023     133244       QB              78.6
#
#    aimed_passes  attempts  avg_time_to_throw  btt_rate  completion_percent  \
# 0           517       556               2.68       7.3                65.5
# 1           525       556               2.52       3.4                64.7
# 2           495       526               2.80       5.1                62.9
# 3           457       502               2.46       3.8                60.6
# 4           444       486               2.80       4.8                66.7
#
#    drop_rate  qb_rating   yards
# 0        5.5      106.7  4906.0
# 1        8.6       84.6  3786.0
# 2        8.3       87.8  3525.0
# 3        7.3       79.6  3460.0
# 4        7.2      100.7  3723.0

# %%
college_qb.shape
# Out:
# (3608, 13)

# %%
numerical_cols = college_qb.columns[[is_numeric_dtype(col) for col in college_qb.dtypes]]

fig, axes = plt.subplots(nrows=len(numerical_cols), ncols=1, figsize=(15, 25))

for i, column in enumerate(numerical_cols):
    ax = axes[i]
    ax.hist(college_qb[column].dropna(), bins=20, edgecolor='black')
    ax.set_title(column)
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')
    
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
accuracy_threshold = college_qb.accuracy_percent.mean() + college_qb.accuracy_percent.std()

# %%
high_accuracy_qb = college_qb[college_qb.accuracy_percent > accuracy_threshold]

# %%
high_accuracy_qb.head()
# Out:
#              player  year  player_id position  accuracy_percent  aimed_passes  \
# 8            Bo Nix  2023      97790       QB              85.5           454
# 207  Caden Veltkamp  2023     156642       QB              86.3            51
# 270      Ty Simpson  2023     157008       QB              88.2            17
# 283     John Mateer  2023     158516       QB              87.5            16
# 284     Jack Tuttle  2023      83580       QB              93.8            16
#
#      attempts  avg_time_to_throw  btt_rate  completion_percent  drop_rate  \
# 8         467               2.44       4.1                77.3        7.0
# 207        54               2.55       5.2                75.9        6.8
# 270        21               2.92       4.5                57.1       20.0
# 283        17               2.64       5.6                76.5        7.1
# 284        17               2.85       0.0                88.2        0.0
#
#      qb_rating   yards
# 8        135.7  4454.0
# 207      118.1   384.0
# 270       85.2   179.0
# 283      132.6   235.0
# 284      118.1   130.0

# %%
numerical_cols = college_qb.columns[[is_numeric_dtype(col) for col in college_qb.dtypes]]

fig, axes = plt.subplots(nrows=len(numerical_cols), ncols=1, figsize=(15, 25))

for i, column in enumerate(numerical_cols):
    ax = axes[i]
    ax.hist(high_accuracy_qb[column].dropna(), bins=20, edgecolor='black')
    ax.set_title(column)
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')
    
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
